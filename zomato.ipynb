# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.11.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/HP/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/zomato.csv")

# %%
data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
# getting informatiion of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
# first 10 by default
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
# last 10 by default
data.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
# ḷooking for comuns
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.shape
# Out:
# (51717, 17)

# %%
# Data Cleaning:

# Deleting redundant columns.
# Renaming the columns.
# Dropping duplicates.
# Cleaning individual columns.
# Remove the NaN values from the dataset
# Check for some more Transformations

# %%
# Deleting redundant columns.

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
columns_to_keep = ['name', 'online_order', 'book_table','rate','dish_liked','approx_cost(for two people)']
columns_to_drop = ['url', 'address','votes','phone', 'location', 'cuisines','rest_type', 'reviews_list', 'menu_item','listed_in(type)', 'listed_in(city)']

# %%
data[columns_to_keep]
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data[columns_to_drop]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  votes  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...    775
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...    787
# 2      1112, Next to KIMS Medical College, 17th Cross...    918
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %%
len(columns_to_keep)
# Out:
# 6

# %%
len(columns_to_drop)
# Out:
# 11

# %% [markdown]
# # 1st way -- Filtering Data

# %%
modified_data = data[columns_to_keep]

# %%
modified_data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # 2and way - Filtering Data

# %%
# Droping the columns

# %%
columns_to_drop
# Out:
# ['url',
#  'address',
#  'votes',
#  'phone',
#  'location',
#  'cuisines',
#  'rest_type',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
data.drop(columns = columns_to_drop, inplace = True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # Rename Columns

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='object')

# %%
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx_cost(for two people)

# %%
new_columns_name = []
for i in data.columns:
    new_columns_name.append(i.capitalize())

# %%
new_columns_name
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
# changing column name
data.columns = new_columns_name

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Dropping Duplicate

# %%
# getting duplicate 
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# Length: 51717, dtype: bool

# %%
# sum of non duplicates
data.duplicated().sum()
# Out:
# np.int64(32808)

# %%
# counting duplicates 
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
# droping duplicates
data.drop_duplicates(inplace = True)

# %%
# usm of duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51631                                      Just Parathas           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Removing NaN Value

# %%
data.isnull().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
# fixing index :-  some row are mising
data.reset_index(inplace = True)

# %%
data
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
# droping old index
data.drop(columns = "index", inplace = True)

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Cleaning Column

# %%
data["Rate"][14]
# Out:
# '3.9/5'

# %%
c = type(data["Rate"][14])

# %%
c
# Out:
# str

# %%
# Removing spaces with no spaces
data["Rate"] = data["Rate"].str.replace(" ","")
data["Rate"]
# Out:
# 0       4.1/5
# 1       4.1/5
# 2       3.8/5
# 3       3.7/5
# 4       3.8/5
#         ...
# 8245    2.5/5
# 8246    3.6/5
# 8247    3.8/5
# 8248    4.2/5
# 8249    2.5/5
# Name: Rate, Length: 8250, dtype: object

# %%
# showing ratinf out of
data["Rate"] = data["Rate"].str.replace("/"," out of ")
data["Rate"]
# Out:
# 0       4.1 out of 5
# 1       4.1 out of 5
# 2       3.8 out of 5
# 3       3.7 out of 5
# 4       3.8 out of 5
#             ...
# 8245    2.5 out of 5
# 8246    3.6 out of 5
# 8247    3.8 out of 5
# 8248    4.2 out of 5
# 8249    2.5 out of 5
# Name: Rate, Length: 8250, dtype: object

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %%
data["Online_order"] = data["Online_order"].apply(lambda x : 1 if x == "Yes" else 0)

# %%
data
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
data.to_csv("Cleaned Data.csv")

# %%
pd.read_csv("Cleaned Data.csv")
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
data.to_csv("Cleaned Data.csv",index = False)
